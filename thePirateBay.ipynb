# %%
from lxml import html
import requests

# URL key for HD tvshows
CONST_HD_TVSHOW = '208'
# URL key for type of sorting, descending
CONST_SORT_BY = { 'seeds': '8'
                , 'upload_date': '3' }
TORRENTS_FOLDERS = [ 'D:/torrents/unsorted'
                   , 'D:/torrents/tvseries' ]
                   # mind the forward slash on Windows
WATCHED_SERIES = [ 'expanse'
                 , 'x-files'
                 , 'flash']
PROXYBAY_URL = "https://proxybay.la/"

def load_proxies():
    page = requests.get(PROXYBAY_URL)
    tree = html.fromstring(page.content)
    
    urls   = tree.xpath('//a[@rel="nofollow"]/@href')
    states = tree.xpath('//td[@class="status"]/img/@alt')
    speeds = tree.xpath('//td[@class="speed"]/text()')
    
    return zip(urls, states, speeds)

def get_fastest_proxies():
    p = load_proxies()
    p = filter(lambda x: x[1] == 'up', p)
    p.sort(key=lambda t: t[2])
    return map(lambda t: t[0], p[2:]) # throw out the first two, just in case

    # it's actually third fastest, but oh well
def get_fastest_proxy():
    return get_fastest_proxies()[0]

def load_tpb_video(title, sort_by):
    """Returns a list of tuples of (torrent name, description, magnet link)"""
    
    base_url = 'https://tpb.proxyduck.net'#get_fastest_proxy()
    query = '/search/' + title + '/0/' + CONST_SORT_BY[sort_by] + '/' + CONST_HD_TVSHOW
    page = requests.get(base_url + query)                # https://thepiratebay.se/search/x-files/0/3/208
    if page.status_code == 404:
        page = requests.get(base_url + '/?load=' + query)# https://tpb.proxyduck.net/?load=/search/24/0/3/208

    tree = html.fromstring(page.content)
    names = tree.xpath('//a[@class="detLink"]/text()')
    descs = tree.xpath('//font[@class="detDesc"]/text()')
    magnets = tree.xpath('//a[@title="Download this torrent using magnet"]/@href')
    return zip(names, descs, magnets)

from IPython.display import HTML    

def get_links_for_episode(title, sort_by):
    """Returns a list of HTML links that pop up when searching for $title$"""
    htmls = []

    for a,b,c in load_tpb_video(title, sort_by):
        htmls.append('<a href="' + c + '">' + a + ", " + b[:-10] + '</a><br>')
        # b[:-10] cuts the ", ULed By" part from the end, because we're not scrapping the name anyway

    return htmls

def join_all_links(htmls):
    "".join(htmls)
    
def join_top_links(htmls):
    if htmls:
        return "".join(htmls[:3])
    else:
        return ""

# Checking the most recent episodes in the torrents folders
import re, string, os

def list_downloaded_episodes(series):
    """Searches in the TORRENTS_FOLDERS for files containing $series$ and S\d\dE\d\d. Returns a list of dicts"""
    files = []
    for f in TORRENTS_FOLDERS:
        files += os.listdir(f)
    filtered = filter(lambda(x): string.find(string.lower(x), series) != -1, files)
    eps = []
    for f in filtered:
        match = re.search('(?:S)(?P<S>\d\d)(?:E)(?P<E>\d\d)', f)
        if match:
            eps.append ({ 'S': match.group('S')
                        , 'E': match.group('E') })
    return eps # that's a list of dicts!

def last_downloaded_episode(series):
    if list_downloaded_episodes(series):
        return list_downloaded_episodes(series)[-1]
    else:
        return { 'S': '01'
               , 'E': '00' }

def episode_to_str(e):
    e1 = e
    if len(str(e1["S"]))<2:
        e1["S"] = '0' + str(e1["S"])
    
    if len(str(e1["E"]))<2:
        e1["E"] = '0' + str(e1["E"])
        
    return 'S' + e1['S'] + 'E' + e1['E']

import json
from itertools import dropwhile

def next_episode(title, current_episode):
    """Uses tvmaze api to look it up""" # http://www.tvmaze.com/api
    
    # Unpacking the episode dict
    season  = int(current_episode['S'])
    episode = int(current_episode['E'])
    
    series_page = requests.get('http://api.tvmaze.com/singlesearch/shows?q=' + title).content
    series_id = json.loads(series_page)["id"]
    
    episodes_page = requests.get('http://api.tvmaze.com/shows/' + str(series_id) + '/episodes').content
    episodes_json = json.loads(episodes_page)
    
    e = next(dropwhile(lambda e: (e["season"], e["number"])<=(season,episode), episodes_json), None)
    
    if not e:
        return None
    
    e1 = {}
    e1["S"] = str(e["season"])
    e1["E"] = str(e["number"])
    
    return e1

def pprq(dict):
    for d in dict:
        print episode_to_str(d)

def check_for_next_episode(series):
    next_ep = next_episode(series, last_downloaded_episode(series))
    if not next_ep:
        return []
    next_episode_str = episode_to_str(next_ep)
    htmls = get_links_for_episode(series + ' ' + next_episode_str, 'upload_date')
    # if there are many results (meaning, it's popular and old enough),
    # sort by seeds instead
    if len(htmls) > 10:
        htmls = get_links_for_episode(series + ' ' + next_episode_str, 'seeds')
    return htmls

def check_watched_series():
    html = ""
    for s in WATCHED_SERIES:
        links = join_top_links(check_for_next_episode(s))
        if links:
            html += "<font size=+2>" + s.title() + "</font><br>"
            html += join_top_links(check_for_next_episode(s))
            html += "<br>"
    return html

HTML(check_watched_series())
# Out:
# <font size=+2>Expanse</font><br><a href="magnet:?xt=urn:btih:bcdeecd4fc45a39e712baf85b18c27fdf425c0e1&dn=The.Expanse.S01E10.720p.HDTV.x264-KILLERS%5Bettv%5D&tr=udp%3A%2F%2Ftracker.openbittorrent.com%3A80&tr=udp%3A%2F%2Fopen.demonii.com%3A1337&tr=udp%3A%2F%2Ftracker.coppersurfer.tk%3A6969&tr=udp%3A%2F%2Fexodus.desync.com%3A6969">The.Expanse.S01E10.720p.HDTV.x264-KILLERS[ettv], Uploaded 02-03 06:38, Size 854.67 MiB</a><br><br><font size=+2>Flash</font><br><a href="magnet:?xt=urn:btih:ff16fff5d0a5c7c2b8cdfb83a607989dc157c6b5&dn=The+Flash+2014+Season+1+S01E01+720p+web-dl+x264&tr=udp%3A%2F%2Ftracker.openbittorrent.com%3A80&tr=udp%3A%2F%2Fopen.demonii.com%3A1337&tr=udp%3A%2F%2Ftracker.coppersurfer.tk%3A6969&tr=udp%3A%2F%2Fexodus.desync.com%3A6969">The Flash 2014 Season 1 S01E01 720p web-dl x264, Uploaded 10-08 2014, Size 285.81 MiB</a><br><a href="magnet:?xt=urn:btih:516b77f5b18b4fe057e039e685c5d72e63269adb&dn=The+Flash+2014+S01E01+720p+HDTV+X264+-+%5BHeadbangersFC%5D&tr=udp%3A%2F%2Ftracker.openbittorrent.com%3A80&tr=udp%3A%2F%2Fopen.demonii.com%3A1337&tr=udp%3A%2F%2Ftracker.coppersurfer.tk%3A6969&tr=udp%3A%2F%2Fexodus.desync.com%3A6969">The Flash 2014 S01E01 720p HDTV X264 - [HeadbangersFC], Uploaded 10-10 2014, Size 520.33 MiB</a><br><a href="magnet:?xt=urn:btih:dbaa5868ed4b45ebb9a4502466bdc7024444d5ea&dn=The.Flash.2014.S01E01.Pilot.720p.WEB-DL.DD5.1.H.264-YFN&tr=udp%3A%2F%2Ftracker.openbittorrent.com%3A80&tr=udp%3A%2F%2Fopen.demonii.com%3A1337&tr=udp%3A%2F%2Ftracker.coppersurfer.tk%3A6969&tr=udp%3A%2F%2Fexodus.desync.com%3A6969">The.Flash.2014.S01E01.Pilot.720p.WEB-DL.DD5.1.H.264-YFN, Uploaded 10-08 2014, Size 1.5 GiB</a><br><br>

# %%
import PTN

PTN.parse('The.Expanse.S01E09.720p.HDTV.x264-KILLERS[ettv]')
# Out:
# {'codec': 'x264',
#  'episode': 9,
#  'group': 'KILLERS[ettv]',
#  'quality': 'HDTV',
#  'resolution': '720p',
#  'season': 1,
#  'title': 'The Expanse'}

# %%
import subtitle_downloader
        
subtitle_downloader.sub_downloader('The.Expanse.S01E09.720p.HDTV.x264-KILLERS[ettv].mkv')

# %%
import json
from itertools import dropwhile

def lookup_next_episode(title, season, episode):
    series_page = requests.get('http://api.tvmaze.com/singlesearch/shows?q=' + title).content
    series_id = json.loads(series_page)["id"]
    episodes_page = requests.get('http://api.tvmaze.com/shows/' + str(series_id) + '/episodes').content
    episodes_json = json.loads(episodes_page)
    e = dropwhile(lambda e: (e["season"], e["number"])<=(season,episode), episodes_json).next()
    return "s" + str(e["season"]) + "e" + str(e["number"])

lookup_next_episode("x-files", 2, 25)
# Out:
# 's3e1'

# %%
print (1,24) < (2,1)
# Out:
# True

# %%
import json

p = requests.get('http://api.tvmaze.com/singlesearch/shows?q=x-files').content
print json.loads(p)["id"]

def lookup_last_episode(title):
    series_page = requests.get('http://api.tvmaze.com/singlesearch/shows?q=' + title).content
    series_id = json.loads(series_page)["id"]
    episodes_page = requests.get('http://api.tvmaze.com/shows/' + str(series_id) + '/episodes').content
    episodes_json = json.loads(episodes_page)
    #print "s" + str(episodes_json[-1]["season"]) + "e" + str(episodes_json[-1]["number"])
    return episodes_json[-1]["airdate"]
    
#lookup_last_episode("x-files")

import time
from time import mktime
from datetime import datetime

d1 = time.strptime(lookup_last_episode("x-files"), "%Y-%m-%d")
d2 = datetime.now()

print d2 < datetime.fromtimestamp(mktime(d1))
# Out:
# 430
# True

# %%
import json

p = requests.get('http://api.tvmaze.com/shows/430/episodes').content
print json.dumps( json.loads(p)
                 , sort_keys=False
                 , indent=4
                 , separators=(',', ': '))
# Out:
# [
#     {
#         "name": "Pilot",
#         "airdate": "1993-09-10",
#         "url": "http://www.tvmaze.com/episodes/40420/the-x-files-1x01-pilot",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95040.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95040.jpg"
#         },
#         "number": 1,
#         "summary": "<p><span>Special Agent Dana Scully is partnered with \nSpecial Agent Fox Mulder to validate his work on a special project \ncalled The X-Files. While he is a believer in the paranormal, fueled by a\n lost memory where<span> his \nsister was abducted by aliens; she is a scientist and prefers to look \nfor rational, logical explanations. Their first case takes them to \nOregon, to investigate the unsolved deaths of several high school \nclassmates, which Mulder believes are linked to an alien abduction.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40420"
#             }
#         },
#         "airstamp": "1993-09-10T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40420
#     },
#     {
#         "name": "Deep Throat",
#         "airdate": "1993-09-17",
#         "url": "http://www.tvmaze.com/episodes/40421/the-x-files-1x02-deep-throat",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95043.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95043.jpg"
#         },
#         "number": 2,
#         "summary": "<p><span>Mulder and Scully head to Ellens Air Force Base\n to investigate the mysterious case of a military test pilot who \ndisappeared after experiencing strange psychotic behavior. While on the \ncase, Mulder meets a mysterious man dubbed<span> 'Deep Throat', who claims to have classified information about his investigations into the paranormal.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40421"
#             }
#         },
#         "airstamp": "1993-09-17T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40421
#     },
#     {
#         "name": "Squeeze",
#         "airdate": "1993-09-24",
#         "url": "http://www.tvmaze.com/episodes/40422/the-x-files-1x03-squeeze",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94217.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94217.jpg"
#         },
#         "number": 3,
#         "summary": "<p><span>One of Scully's friends from the FBI academy, \nnow working in the Violent Crimes Unit, asks her to assist him on a \nhomicide investigation involving no clear point of entry. Mulder \nrealizes that this is similar<span> to a series of X-Files case that have occurred every thirty years, and joins in the investigation to stop the latest cycle.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40422"
#             }
#         },
#         "airstamp": "1993-09-24T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40422
#     },
#     {
#         "name": "Conduit",
#         "airdate": "1993-10-01",
#         "url": "http://www.tvmaze.com/episodes/40423/the-x-files-1x04-conduit",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94224.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94224.jpg"
#         },
#         "number": 4,
#         "summary": "<p>As Section Chief Blevins expresses his concern with the direction of the\n X-Files department, Mulder becomes obsessed with solving a case that \nclosely parallels an 'encounter' he experienced as a child... the \nabduction of his kid sister, Samantha.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40423"
#             }
#         },
#         "airstamp": "1993-10-01T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40423
#     },
#     {
#         "name": "The Jersey Devil",
#         "airdate": "1993-10-08",
#         "url": "http://www.tvmaze.com/episodes/40424/the-x-files-1x05-the-jersey-devil",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94236.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94236.jpg"
#         },
#         "number": 5,
#         "summary": "<p><span>Mulder's trip to Atlantic City doesn't take him\n to the glittering casinos or luxury hotels. Instead, he plays a \ndangerous game of hunter-and-hunted with the maneater that haunts the \nback alleys and woods surrounding the city.<span> However,\n it's not long before even Scully, the eternal skeptic, is lured back by\n the mounting evidence Mulder manages to drag out of tourist-wary local \nlaw enforcement agencies.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40424"
#             }
#         },
#         "airstamp": "1993-10-08T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40424
#     },
#     {
#         "name": "Shadows",
#         "airdate": "1993-10-22",
#         "url": "http://www.tvmaze.com/episodes/40425/the-x-files-1x06-shadows",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94240.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94240.jpg"
#         },
#         "number": 6,
#         "summary": "<p>When an unseen force commits several murders where a young woman is \npresent, Mulder suspects that it is the spirit of the woman's former \nboss protecting her, while Scully believes the boss merely faked his own\n death.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40425"
#             }
#         },
#         "airstamp": "1993-10-22T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40425
#     },
#     {
#         "name": "Ghost in the Machine",
#         "airdate": "1993-10-29",
#         "url": "http://www.tvmaze.com/episodes/40426/the-x-files-1x07-ghost-in-the-machine",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94244.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94244.jpg"
#         },
#         "number": 7,
#         "summary": "<p><span>A new intelligence gropes its way to life in \nthe depths of wires and circuit boards - only to find itself perched on \nthe edge of immediate extinction. When it fights back, killing Mulder's \nformer partner<span> in the process, he and Scully must find a way past its considerable defences.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40426"
#             }
#         },
#         "airstamp": "1993-10-29T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40426
#     },
#     {
#         "name": "Ice",
#         "airdate": "1993-11-05",
#         "url": "http://www.tvmaze.com/episodes/40427/the-x-files-1x08-ice",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94259.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94259.jpg"
#         },
#         "number": 8,
#         "summary": "<p><span>When an Arctic research team mysteriously kills\n each other and themselves only days after drilling deeper into the ice \nthan ever before, Mulder and Scully accompany a team of doctors and \nscientists to investigate. They discover<span> an\n organism which infects living creatures and amplifies the host's \nfeeling of anger and paranoia, and the new team starts to deteriorate as\n they wonder who among them are killers.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40427"
#             }
#         },
#         "airstamp": "1993-11-05T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40427
#     },
#     {
#         "name": "Space",
#         "airdate": "1993-11-12",
#         "url": "http://www.tvmaze.com/episodes/40428/the-x-files-1x09-space",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94272.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94272.jpg"
#         },
#         "number": 9,
#         "summary": "<p>Mulder and Scully are contacted by a communications specialist from NASA\n who shows them evidence of sabotage in the space programme. Mulder's \nyouthful hero-worship is shaken by the apparent involvement of a \nhigh-ranking astronaut.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40428"
#             }
#         },
#         "airstamp": "1993-11-12T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40428
#     },
#     {
#         "name": "Fallen Angel",
#         "airdate": "1993-11-19",
#         "url": "http://www.tvmaze.com/episodes/40429/the-x-files-1x10-fallen-angel",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94274.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94274.jpg"
#         },
#         "number": 10,
#         "summary": "<p><span>When a tract of lonely woodland is cordoned off\n between laser fences, and rapidly changing explanations are rampant, \nMulder's curiosity carries him beyond the bounds of official \njurisdiction-and into the middle of a UFO cleanup. Scully's<span> attempts\n to protect Mulder from himself are only marginally successful, and \nneither agents seem capable of protecting the one innocent on the scene-\n Max Fenig.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40429"
#             }
#         },
#         "airstamp": "1993-11-19T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40429
#     },
#     {
#         "name": "Eve",
#         "airdate": "1993-12-10",
#         "url": "http://www.tvmaze.com/episodes/40430/the-x-files-1x11-eve",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94441.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94441.jpg"
#         },
#         "number": 11,
#         "summary": "<p><span>When two fathers on opposite sides of the \ncountry are unexplainably murdered at the exact same time in the exact \nsame way, Mulder and Scully are called in to investigate. When they \ndiscover that both of<span> the fathers eight-year-old daughters are identical twins, they realize that something even stranger is going on.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40430"
#             }
#         },
#         "airstamp": "1993-12-10T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40430
#     },
#     {
#         "name": "Fire",
#         "airdate": "1993-12-17",
#         "url": "http://www.tvmaze.com/episodes/40431/the-x-files-1x12-fire",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94443.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94443.jpg"
#         },
#         "number": 12,
#         "summary": "<p>When an old Oxford girlfriend of Mulder's asks for his help in an \ninternational case concerning the unexplainable execution of several \nBritish dignitaries they encounter an assassin who can produce fire from\n his bare hands.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40431"
#             }
#         },
#         "airstamp": "1993-12-17T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40431
#     },
#     {
#         "name": "Beyond the Sea",
#         "airdate": "1994-01-07",
#         "url": "http://www.tvmaze.com/episodes/40432/the-x-files-1x13-beyond-the-sea",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94445.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94445.jpg"
#         },
#         "number": 13,
#         "summary": "<p><span>Scully has a brush with the paranormal when her\n recently deceased father appears to her in a vision. Meanwhile, Mulder \nbecomes a skeptic when a death row inmate he helped send to prison \nclaims to be<span> a psychic and offers to lead the agents to a serial killer.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40432"
#             }
#         },
#         "airstamp": "1994-01-07T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40432
#     },
#     {
#         "name": "Gender Bender",
#         "airdate": "1994-01-21",
#         "url": "http://www.tvmaze.com/episodes/40433/the-x-files-1x14-gender-bender",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94459.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94459.jpg"
#         },
#         "number": 14,
#         "summary": "<p>Mulder and Scully investigate a series of murders where the suspect \nseems to be both male and female. Their investigation leads them to the \nsmall town of Stevenston, Massachusetts, where a group called the \nKindred have set up a village back in the woods.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40433"
#             }
#         },
#         "airstamp": "1994-01-21T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40433
#     },
#     {
#         "name": "Lazarus",
#         "airdate": "1994-02-04",
#         "url": "http://www.tvmaze.com/episodes/40434/the-x-files-1x15-lazarus",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94469.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94469.jpg"
#         },
#         "number": 15,
#         "summary": "<p>When FBI Agent Jack Willis is shot during a bank robbery, Agent Scully \ntakes drastic steps to resuscitate him while the bank robber, Warren \nDupre dies on the operating table. Afterward, Agent Willis begins to \nexhibit behavior strangely reminiscent of Dupre.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40434"
#             }
#         },
#         "airstamp": "1994-02-04T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40434
#     },
#     {
#         "name": "Young at Heart",
#         "airdate": "1994-02-11",
#         "url": "http://www.tvmaze.com/episodes/40435/the-x-files-1x16-young-at-heart",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94561.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94561.jpg"
#         },
#         "number": 16,
#         "summary": "<p>Mulder becomes the target of someone from his past, John Barnett, a \njewelry store robber with an itchy trigger finger that Mulder sent to \nprison when he first joined the Bureau. The only problem is that Barnett\n died four years ago.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40435"
#             }
#         },
#         "airstamp": "1994-02-11T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40435
#     },
#     {
#         "name": "E.B.E.",
#         "airdate": "1994-02-18",
#         "url": "http://www.tvmaze.com/episodes/40436/the-x-files-1x17-ebe",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94627.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94627.jpg"
#         },
#         "number": 17,
#         "summary": "<p><span>A dramatic increase in UFO sightings and a \nbizarre attack on a transport truck convince Mulder that he's on the \ntrail of a live alien being covertly transported cross-country. For her \npart, Scully, equally wary of<span> the involvement of the Lone Gunmen as she is of Deep Throat, suspects a rather more earthly explanation.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40436"
#             }
#         },
#         "airstamp": "1994-02-18T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40436
#     },
#     {
#         "name": "Miracle Man",
#         "airdate": "1994-03-18",
#         "url": "http://www.tvmaze.com/episodes/40437/the-x-files-1x18-miracle-man",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94648.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94648.jpg"
#         },
#         "number": 18,
#         "summary": "<p><span>A rash of deaths under the Miracle Ministry's \ntraveling tent brings Scully and Mulder into the realm of miracles and \nshysters. When Samuel, reputed raiser of the dead and healer of the \nsick, indicates he has<span> some knowledge of Mulder's long lost sister, Scully's convinced the young man is setting them up. Mulder isn't so sure.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40437"
#             }
#         },
#         "airstamp": "1994-03-18T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40437
#     },
#     {
#         "name": "Shapes",
#         "airdate": "1994-04-01",
#         "url": "http://www.tvmaze.com/episodes/40438/the-x-files-1x19-shapes",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94701.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94701.jpg"
#         },
#         "number": 19,
#         "summary": "<p>Mulder and Scully travel to an American Indian reservation to \ninvestigate the death of an Indian man who was mistaken for a wild \nanimal and may have been the legendary Manitou, a man who can shapeshift\n into a beast.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40438"
#             }
#         },
#         "airstamp": "1994-04-01T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40438
#     },
#     {
#         "name": "Darkness Falls",
#         "airdate": "1994-04-15",
#         "url": "http://www.tvmaze.com/episodes/40439/the-x-files-1x20-darkness-falls",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94713.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94713.jpg"
#         },
#         "number": 20,
#         "summary": "<p><span>When a group of loggers in the Washington State\n National Forest disappear in the same way that another group \ndisappeared 50 years ago, Mulder and Scully go along to investigate and \nfind themselves trapped in a<span> cabin surrounded by flesh eating insects that only attack at night.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40439"
#             }
#         },
#         "airstamp": "1994-04-15T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40439
#     },
#     {
#         "name": "Tooms",
#         "airdate": "1994-04-22",
#         "url": "http://www.tvmaze.com/episodes/40440/the-x-files-1x21-tooms",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94738.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94738.jpg"
#         },
#         "number": 21,
#         "summary": "<p>Eugene Tooms, the genetic mutant, is released from the sanitarium and \nMulder becomes personally involved to ensure that he is caught in the \nact of getting the last human liver he needs to go into hibernation for \nanother 30 years.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40440"
#             }
#         },
#         "airstamp": "1994-04-22T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40440
#     },
#     {
#         "name": "Born Again",
#         "airdate": "1994-04-29",
#         "url": "http://www.tvmaze.com/episodes/40441/the-x-files-1x22-born-again",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95062.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95062.jpg"
#         },
#         "number": 22,
#         "summary": "<p>After a detective and his former partner die in unexplained \ncircumstances, the accidents are linked to a little girl who witnessed \nboth deaths and Mulder believes that she may be the reincarnation of a \npoliceman murdered by his colleagues.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40441"
#             }
#         },
#         "airstamp": "1994-04-29T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40441
#     },
#     {
#         "name": "Roland",
#         "airdate": "1994-05-06",
#         "url": "http://www.tvmaze.com/episodes/40442/the-x-files-1x23-roland",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95073.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95073.jpg"
#         },
#         "number": 23,
#         "summary": "<p>When a series of murders occur among a group of scientists working on \nadvanced propulsion technology, Mulder and Scully are called in to \ninvestigate. All evidence seems to point to the janitor Roland, who is \nmentally handicapped.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40442"
#             }
#         },
#         "airstamp": "1994-05-06T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40442
#     },
#     {
#         "name": "The Erlenmeyer Flask",
#         "airdate": "1994-05-13",
#         "url": "http://www.tvmaze.com/episodes/40443/the-x-files-1x24-the-erlenmeyer-flask",
#         "season": 1,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95082.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95082.jpg"
#         },
#         "number": 24,
#         "summary": "<p><span>When Deep Throat points out a news story about a\n fugitive who apparently drowned, Mulder and Scully cannot see what \nmakes the case special but they follow it up anyway. With Deep Throat's \ninsistence, they discover<span> evidence\n of secret government project code-named Purity Control, which uses \nhuman test subjects and infects them with extraterrestrial DNA. However,\n the evidence and everyone who has seen it is quickly being eliminated.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40443"
#             }
#         },
#         "airstamp": "1994-05-13T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40443
#     },
#     {
#         "name": "Little Green Men",
#         "airdate": "1994-09-16",
#         "url": "http://www.tvmaze.com/episodes/40444/the-x-files-2x01-little-green-men",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95092.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95092.jpg"
#         },
#         "number": 1,
#         "summary": "<p><span>With the X-Files closed, Scully has been \nassigned as an instructor at the FBI Academy while Mulder is doing \nmenial surveillance work. After meeting with Senator Matheson, one of \nhis supporters in regards to The X-Files,<span> Mulder\n disobeys orders and heads to an abandoned SETI site in Puerto Rico \nwhich has unexplainably reactivated itself and could provide proof of \ncontact with extra-terrestrial life.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40444"
#             }
#         },
#         "airstamp": "1994-09-16T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40444
#     },
#     {
#         "name": "The Host",
#         "airdate": "1994-09-23",
#         "url": "http://www.tvmaze.com/episodes/40445/the-x-files-2x02-the-host",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95094.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95094.jpg"
#         },
#         "number": 2,
#         "summary": "<p>AD Skinner sends Mulder to investigate a body which washed into the New \nJersey sewer from the ocean. Mulder believes that the basic blue-collar \nassignment is punishment, but on Skinner's own admission what he \ndiscovers is a true X-File.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40445"
#             }
#         },
#         "airstamp": "1994-09-23T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40445
#     },
#     {
#         "name": "Blood",
#         "airdate": "1994-09-30",
#         "url": "http://www.tvmaze.com/episodes/40446/the-x-files-2x03-blood",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95096.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95096.jpg"
#         },
#         "number": 3,
#         "summary": "<p>When several violent deaths in a small farming community are connected \nby the destruction of digital devices, Mulder believes that people are \nbeing driven to kill by the use of subliminal messages in the digital \nreadouts.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40446"
#             }
#         },
#         "airstamp": "1994-09-30T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40446
#     },
#     {
#         "name": "Sleepless",
#         "airdate": "1994-10-07",
#         "url": "http://www.tvmaze.com/episodes/40447/the-x-files-2x04-sleepless",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95105.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95105.jpg"
#         },
#         "number": 4,
#         "summary": "<p><span>Mulder reluctantly accepts a new partner, Agent\n Alex Krycek, and requests a strange case because someone put an audio \ntape in his morning paper. When his request is granted they investigate \nthe deaths of several Green<span> Beret\n soldiers who participated in a sleep deprivation experiment during the \nVietnam war. But before long it becomes clear that not one of these men \nhave slept in over 20 years.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40447"
#             }
#         },
#         "airstamp": "1994-10-07T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40447
#     },
#     {
#         "name": "Duane Barry (1)",
#         "airdate": "1994-10-14",
#         "url": "http://www.tvmaze.com/episodes/40448/the-x-files-2x05-duane-barry-1",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95683.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95683.jpg"
#         },
#         "number": 5,
#         "summary": "<p><span>Mulder is called to a hostage situation \ninvolving Duane Barry, a former FBI Agent who claims to be an alien \nabductee and wants to get back to the abduction site with someone who \nwill be taken<span> instead of him. Unfortunately, the someone he eventually chooses is Scully.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40448"
#             }
#         },
#         "airstamp": "1994-10-14T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40448
#     },
#     {
#         "name": "Ascension (2)",
#         "airdate": "1994-10-21",
#         "url": "http://www.tvmaze.com/episodes/40449/the-x-files-2x06-ascension-2",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95759.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95759.jpg"
#         },
#         "number": 6,
#         "summary": "<p>When Mulder finds out that Scully was kidnapped by Duane Barry, he risks\n the wrath of his superiors and the annoyance of Agent Krycek in order \nto do whatever it takes to find her. Meanwhile, Krycek is found to be \nreporting Mulder's activities to the CSM.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40449"
#             }
#         },
#         "airstamp": "1994-10-21T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40449
#     },
#     {
#         "name": "3",
#         "airdate": "1994-11-04",
#         "url": "http://www.tvmaze.com/episodes/40450/the-x-files-2x07-3",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95774.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95774.jpg"
#         },
#         "number": 7,
#         "summary": "<p><span>Truly alone for the first time since Scully \nfound her way to the basement of the J. Edger Hoover Building, Mulder \nthrows himself into his work, and into the bizarre world of \nvampire-fetishist in search of<span> a trio of serial killers. But Mulder finds himself falling for the one woman that may be the prime suspect.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40450"
#             }
#         },
#         "airstamp": "1994-11-04T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40450
#     },
#     {
#         "name": "One Breath",
#         "airdate": "1994-11-11",
#         "url": "http://www.tvmaze.com/episodes/40451/the-x-files-2x08-one-breath",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/37/94449.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/37/94449.jpg"
#         },
#         "number": 8,
#         "summary": "<p><span>Scully mysteriously appears in a Washington \nhospital, alive but in a coma, and Mulder must fight to keep her alive \nin order to find out what happened to her and who did it to her. \nMeanwhile,<span> Scully fights her own personal battle as she decides whether to stay or go on to the next world.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40451"
#             }
#         },
#         "airstamp": "1994-11-11T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40451
#     },
#     {
#         "name": "Firewalker",
#         "airdate": "1994-11-18",
#         "url": "http://www.tvmaze.com/episodes/40452/the-x-files-2x09-firewalker",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95794.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95794.jpg"
#         },
#         "number": 9,
#         "summary": "<p>Mulder and Scully, reunited at last, head for an active volcano under a \ngeological study and find a deadly life form that can survive in the \nsearing heat of the crater and is killing the scientists to avoid being \ndiscovered.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40452"
#             }
#         },
#         "airstamp": "1994-11-18T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40452
#     },
#     {
#         "name": "Red Museum",
#         "airdate": "1994-12-09",
#         "url": "http://www.tvmaze.com/episodes/40453/the-x-files-2x10-red-museum",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/95832.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/95832.jpg"
#         },
#         "number": 10,
#         "summary": "<p><span>While investigating the connection between the \nabduction of several teenagers and a rural religious cult, Mulder &amp; \nScully discover a secret test being performed on the children using the \n\"Purity Control\" alien DNA from 'The Erlenmeyer<span> Flask' which leads Mulder to the Crew-Cut Man, Deep Throat's murderer.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40453"
#             }
#         },
#         "airstamp": "1994-12-09T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40453
#     },
#     {
#         "name": "Excelsis Dei",
#         "airdate": "1994-12-16",
#         "url": "http://www.tvmaze.com/episodes/40454/the-x-files-2x11-excelsis-dei",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/96115.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/96115.jpg"
#         },
#         "number": 11,
#         "summary": "<p><span>Mulder and Scully investigate when the rape and\n battery of a nurse takes place in a Massachusetts convalescent home. \nThe nurse claims that she was attacked by one of the residents but also \nclaims they were<span> invisible. Mulder and Scully soon discover that it may not be one of the residents after all...</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40454"
#             }
#         },
#         "airstamp": "1994-12-16T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40454
#     },
#     {
#         "name": "Aubrey",
#         "airdate": "1995-01-06",
#         "url": "http://www.tvmaze.com/episodes/40455/the-x-files-2x12-aubrey",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/96136.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/96136.jpg"
#         },
#         "number": 12,
#         "summary": "<p><span>When a detective mysteriously uncovers the \nremains of an FBI agent who disappeared in the 1940s while investigating\n a murder case similar to a modern-day one she is investigating, Mulder \nand Scully believe that the original<span> killer had passed his genetic trait of violence to his grandchild.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40455"
#             }
#         },
#         "airstamp": "1995-01-06T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40455
#     },
#     {
#         "name": "Irresistible",
#         "airdate": "1995-01-13",
#         "url": "http://www.tvmaze.com/episodes/40456/the-x-files-2x13-irresistible",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/96149.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/96149.jpg"
#         },
#         "number": 13,
#         "summary": "<p>A mortuary worker, who gets his thrills from collecting hair and \nfingernails from the dead, begins killing people to expand his collection and sets his seriously disturbed sights on Scully.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40456"
#             }
#         },
#         "airstamp": "1995-01-13T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40456
#     },
#     {
#         "name": "Die Hand die Verletzt",
#         "airdate": "1995-01-27",
#         "url": "http://www.tvmaze.com/episodes/40457/the-x-files-2x14-die-hand-die-verletzt",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/96786.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/96786.jpg"
#         },
#         "number": 14,
#         "summary": "<p>The ritualistic murder of a teenager in a small town gets Mulder and \nScully caught up in a secret occult practice within the local school's \nPTA and a substitute teacher with strange powers.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40457"
#             }
#         },
#         "airstamp": "1995-01-27T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40457
#     },
#     {
#         "name": "Fresh Bones",
#         "airdate": "1995-02-03",
#         "url": "http://www.tvmaze.com/episodes/40458/the-x-files-2x15-fresh-bones",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/96794.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/96794.jpg"
#         },
#         "number": 15,
#         "summary": "<p>While investigating several deaths and murders within a Haitian refugee \ncamp, Mulder and Scully get caught in the middle of a secret war between\n the camp commander and a Voodoo priest.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40458"
#             }
#         },
#         "airstamp": "1995-02-03T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40458
#     },
#     {
#         "name": "Colony (1)",
#         "airdate": "1995-02-10",
#         "url": "http://www.tvmaze.com/episodes/40459/the-x-files-2x16-colony-1",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/96844.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/96844.jpg"
#         },
#         "number": 16,
#         "summary": "<p>After the obituaries of three identical men are e-mailed to Mulder, the \nagents are contacted by a CIA agent who tells them about a Russian Spy \nKiller sent to eliminate evidence of Cold War era Russian clones who had\n infiltrated the American medical establishment.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40459"
#             }
#         },
#         "airstamp": "1995-02-10T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40459
#     },
#     {
#         "name": "End Game (2)",
#         "airdate": "1995-02-17",
#         "url": "http://www.tvmaze.com/episodes/40460/the-x-files-2x17-end-game-2",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/96854.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/96854.jpg"
#         },
#         "number": 17,
#         "summary": "<p><span>The alien bounty hunter kidnaps Scully and \nwants to trade her for Mulder's sister, who is revealed to be a clone \nherself. After the trade goes badly and Mulder discovers the truth about\n Samantha, he tracks<span> the bounty hunter to his ship buried in the arctic ice and demands the whereabouts of his real sister.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40460"
#             }
#         },
#         "airstamp": "1995-02-17T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40460
#     },
#     {
#         "name": "Fearful Symmetry",
#         "airdate": "1995-02-24",
#         "url": "http://www.tvmaze.com/episodes/40461/the-x-files-2x18-fearful-symmetry",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/96869.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/96869.jpg"
#         },
#         "number": 18,
#         "summary": "<p><span>Invisible animals are rampaging through town, \ndestroying property and trampling a federal employee. On arriving in \ntown, the agents begin their search at a nearby zoo with the distinction\n of never being the site of live<span> birth.\n Whether that's because as Mulder suspects, Aliens are 'harvesting'' the\n young or, as Scully insists, an animal rights group determination to \nclose down the zoo, the only reliable witness appears to be a \nhand-signing gorilla named Sophie.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40461"
#             }
#         },
#         "airstamp": "1995-02-24T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40461
#     },
#     {
#         "name": "D\u00f8d Kalm",
#         "airdate": "1995-03-10",
#         "url": "http://www.tvmaze.com/episodes/40462/the-x-files-2x19-dod-kalm",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/96873.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/96873.jpg"
#         },
#         "number": 19,
#         "summary": "<p><span>When half the crew of a Navy ship abandon their\n boat in a life raft and are rescued 18 hours later looking about 60 \nyears older than they should be, Mulder suggests that the ship is<span> caught in a time field which is speeding up their aging.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40462"
#             }
#         },
#         "airstamp": "1995-03-10T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40462
#     },
#     {
#         "name": "Humbug",
#         "airdate": "1995-03-31",
#         "url": "http://www.tvmaze.com/episodes/40463/the-x-files-2x20-humbug",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/97272.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/97272.jpg"
#         },
#         "number": 20,
#         "summary": "<p><span>Mulder and Scully travel to Gibsonton, Florida,\n a town built and populated by circus and sideshow performers to \ninvestigate the death of Jerald Glazebrook, The Alligator Man. While \nsearching for leads on the killer, the agents<span> come across many bizarre characters including the local sheriff who was once known as Jim Jim, the Dog-Faced Boy.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40463"
#             }
#         },
#         "airstamp": "1995-03-31T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40463
#     },
#     {
#         "name": "The Calusari",
#         "airdate": "1995-04-14",
#         "url": "http://www.tvmaze.com/episodes/40464/the-x-files-2x21-the-calusari",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/97291.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/97291.jpg"
#         },
#         "number": 21,
#         "summary": "<p><span>A balloon traveling into the face of the wind \nisn't much of a clue to launch an investigation into a toddler's death, \nbut, on their arrival, a series of bizarre events convinces Scully \nthey're dealing with<span> a \nrare form of child abuse. For his part, Mulder thinks answers may be \nfound with a pair of dead roosters and a group of elderly chanters \ncalled the Calusari.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40464"
#             }
#         },
#         "airstamp": "1995-04-14T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40464
#     },
#     {
#         "name": "F. Emasculata",
#         "airdate": "1995-04-28",
#         "url": "http://www.tvmaze.com/episodes/40465/the-x-files-2x22-f-emasculata",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/97304.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/97304.jpg"
#         },
#         "number": 22,
#         "summary": "<p>When a plaguelike illness kills 10 men inside a maximum security prison,\n Scully tries to get into the quarantine site and discover the cause and\n origin of the contagion, while Mulder and a group of US Marshals track \ntwo escapees who may be infected.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40465"
#             }
#         },
#         "airstamp": "1995-04-28T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40465
#     },
#     {
#         "name": "Soft Light",
#         "airdate": "1995-05-05",
#         "url": "http://www.tvmaze.com/episodes/40466/the-x-files-2x23-soft-light",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/97351.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/38/97351.jpg"
#         },
#         "number": 23,
#         "summary": "<p><span>When people start disappearing, and the case is\n shoved in her general direction, Detective Kelly Ryan, one of Scully's \nformer students, turns to her old teacher for assistance. Mulder's \ntheories, in fact his very presence, become<span> more\n and more un-welcome as the body count continues to mount in his general\n vicinity. Mulder's growing disinclination to share his thoughts on the \ncase in the face of Ryan's- and Scully's!-evident skepticism doesn't \nendear him to the woman, either.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40466"
#             }
#         },
#         "airstamp": "1995-05-05T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40466
#     },
#     {
#         "name": "Our Town",
#         "airdate": "1995-05-12",
#         "url": "http://www.tvmaze.com/episodes/40467/the-x-files-2x24-our-town",
#         "season": 2,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/38/97374.jpg",
# ...
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40611"
#             }
#         },
#         "airstamp": "2002-03-10T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40611
#     },
#     {
#         "name": "Audrey Pauley",
#         "airdate": "2002-03-17",
#         "url": "http://www.tvmaze.com/episodes/40612/the-x-files-9x11-audrey-pauley",
#         "season": 9,
#         "image": null,
#         "number": 11,
#         "summary": "<p><span>Doggett and Scully look for answers that will \nsave Reyes' life after she is injured in a horrible car accident. Yet \nReyes is also fighting to stay alive in the netherworld between life and\n death. But<span> before long Reyes realises that she may have little time left when others in the netherworld start to disappear.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40612"
#             }
#         },
#         "airstamp": "2002-03-17T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40612
#     },
#     {
#         "name": "Underneath",
#         "airdate": "2002-03-31",
#         "url": "http://www.tvmaze.com/episodes/40613/the-x-files-9x12-underneath",
#         "season": 9,
#         "image": null,
#         "number": 12,
#         "summary": "<p>Scully, Doggett and Reyes investigate an old case that Doggett worked on\n as a cop in Brooklyn, dubbed \"The Screwdriver Killer\". They try to \ndetermine whether the man who was convicted and has just been released \nfrom prison was actually the man responsible for the murders.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40613"
#             }
#         },
#         "airstamp": "2002-03-31T21:00:00-05:00",
#         "runtime": 60,
#         "id": 40613
#     },
#     {
#         "name": "Improbable",
#         "airdate": "2002-04-07",
#         "url": "http://www.tvmaze.com/episodes/40614/the-x-files-9x13-improbable",
#         "season": 9,
#         "image": null,
#         "number": 13,
#         "summary": "<p>When Reyes uses numerology to connect the murders of several women to an\n obsessed serial killer, she and Scully become trapped with a mysterious\n checker-playing man who may or may not be the killer. The question then\n becomes who is going to be the next victim.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40614"
#             }
#         },
#         "airstamp": "2002-04-07T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40614
#     },
#     {
#         "name": "Scary Monsters",
#         "airdate": "2002-04-14",
#         "url": "http://www.tvmaze.com/episodes/40615/the-x-files-9x14-scary-monsters",
#         "season": 9,
#         "image": null,
#         "number": 14,
#         "summary": "<p><span>Monsters hiding under a little boy's bed may be\n more than just the product of a vivid imagination when agents Harrison,\n Doggett and Reyes investigate. They find out that there is more to the \nstory of<span> the mysterious \ndeath of the child's mother who apparently stabbed herself repeatedly. \nMeanwhile Scully conducts an autopsy on a dead cat.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40615"
#             }
#         },
#         "airstamp": "2002-04-14T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40615
#     },
#     {
#         "name": "Jump the Shark",
#         "airdate": "2002-04-21",
#         "url": "http://www.tvmaze.com/episodes/40616/the-x-files-9x15-jump-the-shark",
#         "season": 9,
#         "image": null,
#         "number": 15,
#         "summary": "<p><span>When Morris Fletcher approaches agents Doggett \nand Reyes with information related to \"Super Soldiers\", they turn to the\n Lone Gunmen. The Gunmen, however, are knee-deep in a bio-terrorist's \nplot to release a deadly toxin into the<span> population but the Gunmen find that they may have to make the ultimate sacrifice for their cause.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40616"
#             }
#         },
#         "airstamp": "2002-04-21T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40616
#     },
#     {
#         "name": "William",
#         "airdate": "2002-04-28",
#         "url": "http://www.tvmaze.com/episodes/40617/the-x-files-9x16-william",
#         "season": 9,
#         "image": null,
#         "number": 16,
#         "summary": "<p><span>Doggett catches someone in the X-files office \ntrying to steal documents pertaining to Mulder's sister. The intruder is\n a severely scarred man who blames his disfigurement on Government \nconspirators. He claims the source of that information<span> -\n and, in fact, the one who helped him gain entry - is Mulder. Although \nhe refuses to divulge the missing agent's whereabouts, the mystery man \nhas enough knowledge of the X-files and its history to lead Doggett to \nsuspect that he just might be Mulder himself. Scully's fears for the \nsafety of her son are elevated when he is injected with an unknown \nsubstance. With the mystery surrounding William becoming even more \ndarker, Scully must allow herself to send him away for his own safety.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40617"
#             }
#         },
#         "airstamp": "2002-04-28T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40617
#     },
#     {
#         "name": "Release",
#         "airdate": "2002-05-05",
#         "url": "http://www.tvmaze.com/episodes/40618/the-x-files-9x17-release",
#         "season": 9,
#         "image": null,
#         "number": 17,
#         "summary": "<p><span>When an FBI cadet with amazing profiling skills\n approaches Doggett, Reyes and Scully with a lead on a suspect in a \nseries of recent murders, he claims the same killer is responsible for \nthe death of<span> Doggett's \nson. The agents find themselves wondering if his knowledge of the deaths\n is because of his obsession with the cases he has studied at Quantico \nor if he is in some way involved in the murders</span></span>.</p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40618"
#             }
#         },
#         "airstamp": "2002-05-05T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40618
#     },
#     {
#         "name": "Sunshine Days",
#         "airdate": "2002-05-12",
#         "url": "http://www.tvmaze.com/episodes/40619/the-x-files-9x18-sunshine-days",
#         "season": 9,
#         "image": null,
#         "number": 18,
#         "summary": "<p><span>Doggett and Reyes investigate a murder outside \nthe house that the original Brady Bunch series was filmed in. The house \nis owned by a man named Oliver who is obsessed with the show and has \nrigged<span> the house into a \nseries of traps and changing appearances to look like the Brady house. \nHowever the agents soon find out that Oliver could be the proof needed \nthat the X Files has been searching for over the past 9 years.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40619"
#             }
#         },
#         "airstamp": "2002-05-12T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40619
#     },
#     {
#         "name": "The Truth (1)",
#         "airdate": "2002-05-19",
#         "url": "http://www.tvmaze.com/episodes/40620/the-x-files-9x19-the-truth-1",
#         "season": 9,
#         "image": null,
#         "number": 19,
#         "summary": "<p><span>After not knowing Fox Mulder's whereabouts for \nthe last year, A.D. Skinner and Agent Scully learn he is being held for \nthe murder of a military man he couldn't possibly have killed: Knowle \nRohrer, one of<span> the \ngovernment's secret super soldiers. With Skinner acting as Mulder's \ndefence, people who Mulder has dealings with during his last nine years \nas an FBI agent testify on his behalf. But the military tribunal isn't \ninterested in the truth. When an unexpected person comes to Mulder's \nrescue, Mulder refuses to slip north over the border to safety. Instead,\n he heads southwest to the Anasazi ruins of New Mexico seeking a \nmysterious wise man whom the Indians call The Keeper of the Truth.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40620"
#             }
#         },
#         "airstamp": "2002-05-19T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40620
#     },
#     {
#         "name": "The Truth (2)",
#         "airdate": "2002-05-19",
#         "url": "http://www.tvmaze.com/episodes/40621/the-x-files-9x20-the-truth-2",
#         "season": 9,
#         "image": null,
#         "number": 20,
#         "summary": "<p><span>After not knowing Fox Mulder's whereabouts for \nthe last year, A.D. Skinner and Agent Scully learn he is being held for \nthe murder of a military man he couldn't possibly have killed: Knowle \nRohrer, one of<span> the \ngovernment's secret super soldiers. With Skinner acting as Mulder's \ndefence, people who Mulder has dealings with during his last nine years \nas an FBI agent testify on his behalf. But the military tribunal isn't \ninterested in the truth. When an unexpected person comes to Mulder's \nrescue, Mulder refuses to slip north over the border to safety. Instead,\n he heads southwest to the Anasazi ruins of New Mexico seeking a \nmysterious wise man whom the Indians call The Keeper of the Truth.</span></span></p>",
#         "airtime": "21:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/40621"
#             }
#         },
#         "airstamp": "2002-05-19T21:00:00-04:00",
#         "runtime": 60,
#         "id": 40621
#     },
#     {
#         "name": "My Struggle",
#         "airdate": "2016-01-24",
#         "url": "http://www.tvmaze.com/episodes/181907/the-x-files-10x01-my-struggle",
#         "season": 10,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/41/102918.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/41/102918.jpg"
#         },
#         "number": 1,
#         "summary": "<p>Thirteen years after the original series run, the next mind-bending \nchapter of the thrilling series THE X-FILES has arrived. Fox Mulder and Dana Scully have been contacted \nby Tad O'Malley, a popular conspiracy theorist \nweb-TV show host who believes he has uncovered a significant government \nconspiracy. With the assistance of FBI Asst. Dir. Walter Skinner, O'Malley seeks to enlist the help of former X-Files agents \nMulder and Scully, who have since severed ties with the FBI. Through \nO'Malley they are introduced to Sveta, a \npossible alien abductee who shares shocking information with them that \nwill challenge everything that Mulder has ever believed about the \nexistence of aliens and the government's role in covering them up.</p>",
#         "airtime": "22:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/181907"
#             }
#         },
#         "airstamp": "2016-01-24T22:00:00-05:00",
#         "runtime": 60,
#         "id": 181907
#     },
#     {
#         "name": "Founder's Mutation",
#         "airdate": "2016-01-25",
#         "url": "http://www.tvmaze.com/episodes/215950/the-x-files-10x02-founders-mutation",
#         "season": 10,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/42/106422.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/42/106422.jpg"
#         },
#         "number": 2,
#         "summary": "<p>When a scientist suddenly kills himself, Mulder and Scully's investigation leads to a laboratory where extreme genetic experimentation has been breeding subjects with dangerous powers.</p>",
#         "airtime": "20:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/215950"
#             }
#         },
#         "airstamp": "2016-01-25T20:00:00-05:00",
#         "runtime": 60,
#         "id": 215950
#     },
#     {
#         "name": "Mulder and Scully Meet the Were-Monster",
#         "airdate": "2016-02-01",
#         "url": "http://www.tvmaze.com/episodes/306785/the-x-files-10x03-mulder-and-scully-meet-the-were-monster",
#         "season": 10,
#         "image": {
#             "medium": "http://tvmazecdn.com/uploads/images/medium_landscape/42/106415.jpg",
#             "original": "http://tvmazecdn.com/uploads/images/original_untouched/42/106415.jpg"
#         },
#         "number": 3,
#         "summary": "<p>Witnesses claim a strange creature was responsible for killing a person in the woods; Mulder confronts some of his own demons.</p>",
#         "airtime": "20:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/306785"
#             }
#         },
#         "airstamp": "2016-02-01T20:00:00-05:00",
#         "runtime": 60,
#         "id": 306785
#     },
#     {
#         "name": "Home Again",
#         "airdate": "2016-02-08",
#         "url": "http://www.tvmaze.com/episodes/306786/the-x-files-10x04-home-again",
#         "season": 10,
#         "image": null,
#         "number": 4,
#         "summary": "<p>Mulder and Scully are sent to investigate the murder of a city official,\n which it seems no human could have committed. Meanwhile, Scully deals \nwith a personal tragedy, which brings up many old feelings about the \nchild she gave away for adoption</p>",
#         "airtime": "20:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/306786"
#             }
#         },
#         "airstamp": "2016-02-08T20:00:00-05:00",
#         "runtime": 60,
#         "id": 306786
#     },
#     {
#         "name": "Babylon",
#         "airdate": "2016-02-15",
#         "url": "http://www.tvmaze.com/episodes/306787/the-x-files-10x05-babylon",
#         "season": 10,
#         "image": null,
#         "number": 5,
#         "summary": "<p>When an art gallery that's showing potentially offensive artwork is bombed, Mulder and Scully seek some way to communicate with the comatose bomber in order to prevent a future attack. Meanwhile, a pair of younger FBI agents on the case (guest stars Robbie Amell and Lauren Ambrose) push Mulder and Scully to examine their own beliefs as Scully seeks answers from neuroscience and Mulder from mysticism.</p>",
#         "airtime": "20:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/306787"
#             }
#         },
#         "airstamp": "2016-02-15T20:00:00-05:00",
#         "runtime": 60,
#         "id": 306787
#     },
#     {
#         "name": "My Struggle II",
#         "airdate": "2016-02-22",
#         "url": "http://www.tvmaze.com/episodes/306788/the-x-files-10x06-my-struggle-ii",
#         "season": 10,
#         "image": null,
#         "number": 6,
#         "summary": "<p>The investigations that Mulder and Scully previously began with conspiracy theorist and web-TV show host Tad O'Malley (guest star Joel McHale) seem to have awakened powerful enemies. A widespread panic begins as people all over the country suddenly start falling gravely ill, and Scully must look within to try and find a cure. Meanwhile, Mulder confronts the man whom he believes to be behind it all, but another figure from Mulder and Scully's past may prove to be the key to their salvation.</p>",
#         "airtime": "20:00",
#         "_links": {
#             "self": {
#                 "href": "http://api.tvmaze.com/episodes/306788"
#             }
#         },
#         "airstamp": "2016-02-22T20:00:00-05:00",
#         "runtime": 60,
#         "id": 306788
#     }
# ]
